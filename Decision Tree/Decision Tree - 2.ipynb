# %% [markdown]
# #### Name: Ananya Godse   SAPID: 60009220161

# %% [markdown]
# # Decision Tree Classifer - Iris Dataset

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# ### Loading the dataset

# %%
iris = pd.read_csv("Iris.csv")
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris.drop(columns=["Id"], inplace=True)
iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Splitting the Training & Testing Data

# %%
X = iris.iloc[:, :-1]
y = iris.iloc[:, -1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7)

# %% [markdown]
# ### Fit & Predict

# %%
# Creating Decision Tree Object
clf = DecisionTreeClassifier()

# %%
# Training the classifier
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# predicting the y labels for testing data
predictions = clf.predict(X_test)
predictions
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica'], dtype=object)

# %% [markdown]
# ### Performance Evaluation

# %%
acc_score = accuracy_score(y_test, predictions)
print(f"Accuracy Score: {acc_score}")
# Out:
# Accuracy Score: 0.9

# %%
classification_rep = classification_report(y_test, predictions)
print(f"Classification Report: \n {classification_rep}")
# Out:
# Classification Report:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         7
# Iris-versicolor       0.91      0.83      0.87        12
#  Iris-virginica       0.83      0.91      0.87        11
#
#        accuracy                           0.90        30
#       macro avg       0.91      0.91      0.91        30
#    weighted avg       0.90      0.90      0.90        30

# %% [markdown]
# ### Visualizing the Decision Tree

# %%
import six
import sys
sys.modules['sklearn.externals.six']=six

# %%
from sklearn.tree import export_graphviz
from IPython.display import Image
import pydotplus
from sklearn.externals.six import StringIO

# %%
dot_data=StringIO()
export_graphviz(clf, out_file=dot_data,
                filled=True, rounded=True,
                special_characters=True, feature_names = iris.keys()[:-1], class_names=['Iris-sentosa','Iris-virginica','Iris-vercicolor'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png('iris1.png')
Image(graph.create_png())

# %% [markdown]
# ### With the criterion as 'entropy'

# %%
clf2 = DecisionTreeClassifier(criterion='entropy')
clf2.fit(X_train, y_train)
predictions2 = clf.predict(X_test)
predictions2
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica'], dtype=object)

# %%
acc_score2 = accuracy_score(y_test, predictions2)
print(f"Accuracy Score: {acc_score2}")
# Out:
# Accuracy Score: 0.9

# %%
classification_rep2 = classification_report(y_test, predictions2)
print(f"Classification Report: \n {classification_rep2}")
# Out:
# Classification Report:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         7
# Iris-versicolor       0.91      0.83      0.87        12
#  Iris-virginica       0.83      0.91      0.87        11
#
#        accuracy                           0.90        30
#       macro avg       0.91      0.91      0.91        30
#    weighted avg       0.90      0.90      0.90        30

# %%
dot_data2=StringIO()
export_graphviz(clf2, out_file=dot_data2,
                filled=True, rounded=True,
                special_characters=True, feature_names = iris.keys()[:-1], class_names=['Iris-sentosa','Iris-virginica','Iris-vercicolor'])
graph2 = pydotplus.graph_from_dot_data(dot_data2.getvalue())
graph2.write_png('iris.png')
Image(graph2.create_png())

# %% [markdown]
# ## Overfitting

# %%
#evaluate decision tree performance on train and test sets with different tree depths
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt

# %%
#synthetic classification dataset
X2, y2 = make_classification(n_samples=10000, n_features=20, n_informative=5, n_redundant=15, random_state=7)
print(X2.shape, y2.shape)
# Out:
# (10000, 20) (10000,)

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.2)

# %%
train_scores = []
test_scores = []
for i in range(1, 21):
    clf3 = DecisionTreeClassifier(max_depth = i)
    clf3.fit(X2_train, y2_train)
    y_pred_train = clf3.predict(X2_train)
    predictions3 = clf3.predict(X2_test)
    train_score = accuracy_score(y2_train, y_pred_train)
    test_score = accuracy_score(y2_test, predictions3)
    print(f"Max Depth = {i} Train Score = {train_score} Test Score ={test_score}")
    train_scores.append(train_score)
    test_scores.append(test_score)
# Out:
# Max Depth = 1 Train Score = 0.798 Test Score =0.7915
# Max Depth = 2 Train Score = 0.809375 Test Score =0.8125
# Max Depth = 3 Train Score = 0.893 Test Score =0.8895
# Max Depth = 4 Train Score = 0.908 Test Score =0.9045
# Max Depth = 5 Train Score = 0.924125 Test Score =0.9175
# Max Depth = 6 Train Score = 0.935625 Test Score =0.924
# Max Depth = 7 Train Score = 0.9475 Test Score =0.9285
# Max Depth = 8 Train Score = 0.959625 Test Score =0.9285
# Max Depth = 9 Train Score = 0.96525 Test Score =0.925
# Max Depth = 10 Train Score = 0.973125 Test Score =0.9335
# Max Depth = 11 Train Score = 0.97925 Test Score =0.934
# Max Depth = 12 Train Score = 0.983125 Test Score =0.928
# Max Depth = 13 Train Score = 0.987625 Test Score =0.9275
# Max Depth = 14 Train Score = 0.990125 Test Score =0.9285
# Max Depth = 15 Train Score = 0.992375 Test Score =0.9265
# Max Depth = 16 Train Score = 0.99475 Test Score =0.9255
# Max Depth = 17 Train Score = 0.9965 Test Score =0.931
# ...

# %%
max_depth = [i for i in range(1, 21)]
plt.plot(max_depth, train_scores, '-o', label="Train")
plt.plot(max_depth, test_scores, '-o', label="Test")
plt.legend()
plt.show()

# %% [markdown]
# The testing accuracy begins to fall somewhere between max depth = 8 and max depth = 9, that is, the classifier is overfitting after max depth = 8
